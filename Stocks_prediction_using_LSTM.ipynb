# %%
#import packages
import pandas as pd
import numpy as np

#to plot within notebook
import matplotlib.pyplot as plt
# %matplotlib inline

#setting figure size
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20,10

#for normalizing data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

#read the file
df = pd.read_csv('NSE-TATAGLOBAL11.csv')

#print the head
df.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-10-08  208.00  222.25  206.85  216.00  215.15             4642146.0
# 1  2018-10-05  217.00  218.60  205.90  210.25  209.20             3519515.0
# 2  2018-10-04  223.50  227.80  216.15  217.25  218.20             1728786.0
# 3  2018-10-03  230.00  237.50  225.75  226.45  227.60             1708590.0
# 4  2018-10-01  234.55  234.60  221.05  230.30  230.90             1534749.0
#
#    Turnover (Lacs)
# 0         10062.83
# 1          7407.06
# 2          3815.79
# 3          3960.27
# 4          3486.05

# %%
#setting index as date
df['Date'] = pd.to_datetime(df.Date,format='%Y-%m-%d')
df.index = df['Date']

#plot
plt.figure(figsize=(16,8))
plt.plot(df['Close'], label='Close Price history')

# %%
# importing libraries
import pandas as pd
import numpy as np

# reading the data
df = pd.read_csv('NSE-TATAGLOBAL11.csv')

# looking at the first five rows of the data
print(df.head())
print('\n Shape of the data:')
print(df.shape)

# setting the index as date
df['Date'] = pd.to_datetime(df.Date,format='%Y-%m-%d')
df.index = df['Date']

#creating dataframe with date and the target variable
data = df.sort_index(ascending=True, axis=0)
new_data = pd.DataFrame(index=range(0,len(df)),columns=['Date', 'Close'])

for i in range(0,len(data)):
     new_data['Date'][i] = data['Date'][i]
     new_data['Close'][i] = data['Close'][i]

# NOTE: While splitting the data into train and validation set, we cannot use random splitting since that will destroy the time component. So here we have set the last year’s data into validation and the 4 years’ data before that into train set.

# splitting into train and validation
train = new_data[:987]
valid = new_data[987:]

# shapes of training set
print('\n Shape of training set:')
print(train.shape)

# shapes of validation set
print('\n Shape of validation set:')
print(valid.shape)

# In the next step, we will create predictions for the validation set and check the RMSE using the actual values.
# making predictions
preds = []
for i in range(0,valid.shape[0]):
    a = train['Close'][len(train)-248+i:].sum() + sum(preds)
    b = a/248
    preds.append(b)

# checking the results (RMSE value)
rms=np.sqrt(np.mean(np.power((np.array(valid['Close'])-preds),2)))
print('\n RMSE value on validation set:')
print(rms)
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-10-08  208.00  222.25  206.85  216.00  215.15             4642146.0
# 1  2018-10-05  217.00  218.60  205.90  210.25  209.20             3519515.0
# 2  2018-10-04  223.50  227.80  216.15  217.25  218.20             1728786.0
# 3  2018-10-03  230.00  237.50  225.75  226.45  227.60             1708590.0
# 4  2018-10-01  234.55  234.60  221.05  230.30  230.90             1534749.0
#
#    Turnover (Lacs)
# 0         10062.83
# 1          7407.06
# 2          3815.79
# 3          3960.27
# 4          3486.05
#
#  Shape of the data:
# (1235, 8)
#
#  Shape of training set:
# (987, 2)
#
#  Shape of validation set:
# (248, 2)
#
#  RMSE value on validation set:
# 104.51415465984348

# %%
#setting index as date values
df['Date'] = pd.to_datetime(df.Date,format='%Y-%m-%d')
df.index = df['Date']

#sorting
data = df.sort_index(ascending=True, axis=0)

#creating a separate dataset
new_data = pd.DataFrame(index=range(0,len(df)),columns=['Date', 'Close'])

for i in range(0,len(data)):
    new_data['Date'][i] = data['Date'][i]
    new_data['Close'][i] = data['Close'][i]

# %%
# !pip install fastai
# Out:
# Requirement already satisfied: fastai in c:\programdata\anaconda3\lib\site-packages (2.5.2)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (from fastai) (0.23.2)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from fastai) (1.1.3)
# Requirement already satisfied: pillow>6.0.0 in c:\programdata\anaconda3\lib\site-packages (from fastai) (8.0.1)
# Requirement already satisfied: fastcore<1.4,>=1.3.8 in c:\programdata\anaconda3\lib\site-packages (from fastai) (1.3.26)
# Requirement already satisfied: pyyaml in c:\programdata\anaconda3\lib\site-packages (from fastai) (5.3.1)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\programdata\anaconda3\lib\site-packages (from fastai) (1.0.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from fastai) (20.4)
# Requirement already satisfied: spacy<4 in c:\programdata\anaconda3\lib\site-packages (from fastai) (3.1.2)
# Requirement already satisfied: pip in c:\programdata\anaconda3\lib\site-packages (from fastai) (20.2.4)
# Requirement already satisfied: torch<1.10,>=1.7.0 in c:\programdata\anaconda3\lib\site-packages (from fastai) (1.9.0)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\programdata\anaconda3\lib\site-packages (from fastai) (0.0.5)
# Requirement already satisfied: torchvision>=0.8.2 in c:\programdata\anaconda3\lib\site-packages (from fastai) (0.10.0)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from fastai) (2.24.0)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from fastai) (1.5.2)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from fastai) (3.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->fastai) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->fastai) (0.17.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->fastai) (1.19.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\lib\site-packages (from pandas->fastai) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\programdata\anaconda3\lib\site-packages (from pandas->fastai) (2020.1)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from packaging->fastai) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->fastai) (2.4.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (0.8.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.8 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (8.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (4.50.2)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (50.3.1.post20201107)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (0.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (3.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (1.8.2)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (0.3.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (2.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (2.0.6)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (2.11.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (2.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (3.0.5)
# Requirement already satisfied: pathy>=0.3.5 in c:\programdata\anaconda3\lib\site-packages (from spacy<4->fastai) (0.6.0)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\lib\site-packages (from torch<1.10,>=1.7.0->fastai) (3.7.4.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->fastai) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->fastai) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->fastai) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->fastai) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->fastai) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->fastai) (0.10.0)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\programdata\anaconda3\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<4->fastai) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2->spacy<4->fastai) (1.1.1)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\programdata\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<4->fastai) (5.2.0)

# %%
# !pip install fastai==0.7.0
# Out:
# Collecting fastai==0.7.0
# WARNING: The candidate selected for download or install is a yanked version: 'torch' candidate (version 0.1.2.post2 at https://files.pythonhosted.org/packages/f8/02/880b468bd382dc79896eaecbeb8ce95e9c4b99a24902874a2cef0b562cea/torch-0.1.2.post2.tar.gz#sha256=a43e37f8f927c5b18f80cd163daaf6a1920edafcab5102e02e3e14bb97d9c874 (from https://pypi.org/simple/torch/))
# Reason for being yanked: 0.1.2 is past it's support date and confuses users on unsupported platforms
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\ProgramData\Anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\prash\\AppData\\Local\\Temp\\pip-install-4dzb_fs1\\torch\\setup.py'"'"'; __file__='"'"'C:\\Users\\prash\\AppData\\Local\\Temp\\pip-install-4dzb_fs1\\torch\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\prash\AppData\Local\Temp\pip-wheel-69dpgsbe'
#        cwd: C:\Users\prash\AppData\Local\Temp\pip-install-4dzb_fs1\torch\
#   Complete output (30 lines):
#   running bdist_wheel
#   running build
#   running build_deps
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#   Using cached fastai-0.7.0-py3-none-any.whl (112 kB)
# Requirement already satisfied: ipython in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (7.19.0)
# Requirement already satisfied: pandas-summary in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (0.0.7)
# Requirement already satisfied: graphviz in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (0.17)
# Requirement already satisfied: PyYAML in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (5.3.1)
# Requirement already satisfied: simplegeneric in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (0.8.1)
# Requirement already satisfied: cycler in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (0.10.0)
# Collecting torchtext
#   Using cached torchtext-0.10.0-cp38-cp38-win_amd64.whl (1.4 MB)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (0.2.5)
# Requirement already satisfied: opencv-python in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (4.5.3.56)
# Requirement already satisfied: traitlets in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (5.0.5)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (0.7.5)
# Requirement already satisfied: entrypoints in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (0.3)
# Requirement already satisfied: ipython-genutils in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (0.2.0)
# Collecting torch<0.4
#   Using cached torch-0.1.2.post2.tar.gz (128 kB)
# Requirement already satisfied: jsonschema in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (3.2.0)
# Requirement already satisfied: bleach in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (3.2.1)
# Requirement already satisfied: seaborn in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (0.11.0)
# Requirement already satisfied: pyzmq in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (19.0.2)
# Requirement already satisfied: Jinja2 in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (2.11.2)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (1.1.3)
# Requirement already satisfied: html5lib in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (1.1)
# Requirement already satisfied: Pygments in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (2.7.2)
# Requirement already satisfied: pytz in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (2020.1)
# Requirement already satisfied: sklearn-pandas in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (2.2.0)
# Requirement already satisfied: pyparsing in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (2.4.7)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (1.5.2)
# Requirement already satisfied: bcolz in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (1.2.1)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (2020.6.20)
# Requirement already satisfied: testpath in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (0.4.4)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (3.3.2)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (4.4.2)
# Requirement already satisfied: ipywidgets in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (7.5.1)
# Collecting plotnine
#   Using cached plotnine-0.8.0-py3-none-any.whl (4.7 MB)
# Requirement already satisfied: ipykernel in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (5.3.4)
# Requirement already satisfied: widgetsnbextension in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (3.5.1)
# Requirement already satisfied: jedi in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (0.17.1)
# Requirement already satisfied: MarkupSafe in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (1.1.1)
# Requirement already satisfied: isoweek in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (1.3.3)
# Requirement already satisfied: Pillow in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (8.0.1)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (0.5.1)
# Requirement already satisfied: torchvision in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (0.10.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (1.19.2)
# Requirement already satisfied: python-dateutil in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (2.8.1)
# Requirement already satisfied: tornado in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (6.0.4)
# Collecting ptyprocess
#   Using cached ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (4.50.2)
# Requirement already satisfied: jupyter in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (1.0.0)
# Requirement already satisfied: feather-format in c:\programdata\anaconda3\lib\site-packages (from fastai==0.7.0) (0.4.1)
# Requirement already satisfied: setuptools>=18.5 in c:\programdata\anaconda3\lib\site-packages (from ipython->fastai==0.7.0) (50.3.1.post20201107)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipython->fastai==0.7.0) (3.0.8)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\lib\site-packages (from ipython->fastai==0.7.0) (0.2.0)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\programdata\anaconda3\lib\site-packages (from ipython->fastai==0.7.0) (0.4.4)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from cycler->fastai==0.7.0) (1.15.0)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from torchtext->fastai==0.7.0) (2.24.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema->fastai==0.7.0) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema->fastai==0.7.0) (20.3.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from bleach->fastai==0.7.0) (20.4)
# Requirement already satisfied: scikit-learn>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from sklearn-pandas->fastai==0.7.0) (0.23.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->fastai==0.7.0) (1.3.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets->fastai==0.7.0) (5.0.8)
# Requirement already satisfied: patsy>=0.5.1 in c:\programdata\anaconda3\lib\site-packages (from plotnine->fastai==0.7.0) (0.5.1)
# Requirement already satisfied: descartes>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from plotnine->fastai==0.7.0) (1.1.0)
# Requirement already satisfied: mizani>=0.7.3 in c:\programdata\anaconda3\lib\site-packages (from plotnine->fastai==0.7.0) (0.7.3)
# Collecting statsmodels>=0.12.1
#   Using cached statsmodels-0.12.2-cp38-none-win_amd64.whl (9.4 MB)
# Requirement already satisfied: jupyter-client in c:\programdata\anaconda3\lib\site-packages (from ipykernel->fastai==0.7.0) (6.1.7)
# Requirement already satisfied: notebook>=4.4.1 in c:\programdata\anaconda3\lib\site-packages (from widgetsnbextension->fastai==0.7.0) (6.1.4)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from jedi->fastai==0.7.0) (0.7.0)
# Requirement already satisfied: jupyter-console in c:\programdata\anaconda3\lib\site-packages (from jupyter->fastai==0.7.0) (6.2.0)
# Requirement already satisfied: nbconvert in c:\programdata\anaconda3\lib\site-packages (from jupyter->fastai==0.7.0) (6.0.7)
# Requirement already satisfied: qtconsole in c:\programdata\anaconda3\lib\site-packages (from jupyter->fastai==0.7.0) (4.7.7)
# Requirement already satisfied: pyarrow>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from feather-format->fastai==0.7.0) (5.0.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->torchtext->fastai==0.7.0) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->torchtext->fastai==0.7.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->torchtext->fastai==0.7.0) (3.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.23.0->sklearn-pandas->fastai==0.7.0) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.23.0->sklearn-pandas->fastai==0.7.0) (0.17.0)
# Requirement already satisfied: jupyter-core in c:\programdata\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->fastai==0.7.0) (4.6.3)
# Requirement already satisfied: palettable in c:\programdata\anaconda3\lib\site-packages (from mizani>=0.7.3->plotnine->fastai==0.7.0) (3.3.0)
# Requirement already satisfied: argon2-cffi in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension->fastai==0.7.0) (20.1.0)
# Requirement already satisfied: Send2Trash in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension->fastai==0.7.0) (1.5.0)
# Requirement already satisfied: prometheus-client in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension->fastai==0.7.0) (0.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension->fastai==0.7.0) (0.9.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->jupyter->fastai==0.7.0) (1.4.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->jupyter->fastai==0.7.0) (0.5.1)
# Requirement already satisfied: jupyterlab-pygments in c:\programdata\anaconda3\lib\site-packages (from nbconvert->jupyter->fastai==0.7.0) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->jupyter->fastai==0.7.0) (0.8.4)
# Requirement already satisfied: defusedxml in c:\programdata\anaconda3\lib\site-packages (from nbconvert->jupyter->fastai==0.7.0) (0.6.0)
#     File "C:\Users\prash\AppData\Local\Temp\pip-install-4dzb_fs1\torch\setup.py", line 225, in <module>
#       setup(name="torch", version="0.1.2.post2",
#     File "C:\ProgramData\Anaconda3\lib\site-packages\setuptools\__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\ProgramData\Anaconda3\lib\distutils\core.py", line 148, in setup
#       dist.run_commands()
#     File "C:\ProgramData\Anaconda3\lib\distutils\dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "C:\ProgramData\Anaconda3\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\ProgramData\Anaconda3\lib\site-packages\wheel\bdist_wheel.py", line 290, in run
#       self.run_command('build')
#     File "C:\ProgramData\Anaconda3\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\ProgramData\Anaconda3\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\ProgramData\Anaconda3\lib\distutils\command\build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "C:\ProgramData\Anaconda3\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\ProgramData\Anaconda3\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\prash\AppData\Local\Temp\pip-install-4dzb_fs1\torch\setup.py", line 51, in run
#       from tools.nnwrap import generate_wrappers as generate_nn_wrappers
#   ModuleNotFoundError: No module named 'tools.nnwrap'
#   ----------------------------------------
#   ERROR: Failed building wheel for torch
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\ProgramData\Anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\prash\\AppData\\Local\\Temp\\pip-install-4dzb_fs1\\torch\\setup.py'"'"'; __file__='"'"'C:\\Users\\prash\\AppData\\Local\\Temp\\pip-install-4dzb_fs1\\torch\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' clean --all
#        cwd: C:\Users\prash\AppData\Local\Temp\pip-install-4dzb_fs1\torch
#   Complete output (2 lines):
#   running clean
#   error: [Errno 2] No such file or directory: '.gitignore'
#   ----------------------------------------
#   ERROR: Failed cleaning build dir for torch
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\ProgramData\Anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\prash\\AppData\\Local\\Temp\\pip-install-4dzb_fs1\\torch\\setup.py'"'"'; __file__='"'"'C:\\Users\\prash\\AppData\\Local\\Temp\\pip-install-4dzb_fs1\\torch\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\prash\AppData\Local\Temp\pip-record-4gnvoro2\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\ProgramData\Anaconda3\Include\torch'
#          cwd: C:\Users\prash\AppData\Local\Temp\pip-install-4dzb_fs1\torch\
#     Complete output (23 lines):
#     running install
#     running build_deps
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\prash\AppData\Local\Temp\pip-install-4dzb_fs1\torch\setup.py", line 225, in <module>
#         setup(name="torch", version="0.1.2.post2",
#       File "C:\ProgramData\Anaconda3\lib\site-packages\setuptools\__init__.py", line 153, in setup
#         return distutils.core.setup(**attrs)
#       File "C:\ProgramData\Anaconda3\lib\distutils\core.py", line 148, in setup
#         dist.run_commands()
#       File "C:\ProgramData\Anaconda3\lib\distutils\dist.py", line 966, in run_commands
#         self.run_command(cmd)
#       File "C:\ProgramData\Anaconda3\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\prash\AppData\Local\Temp\pip-install-4dzb_fs1\torch\setup.py", line 99, in run
#         self.run_command('build_deps')
#       File "C:\ProgramData\Anaconda3\lib\distutils\cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "C:\ProgramData\Anaconda3\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\prash\AppData\Local\Temp\pip-install-4dzb_fs1\torch\setup.py", line 51, in run
#         from tools.nnwrap import generate_wrappers as generate_nn_wrappers
#     ModuleNotFoundError: No module named 'tools.nnwrap'
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\ProgramData\Anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\prash\\AppData\\Local\\Temp\\pip-install-4dzb_fs1\\torch\\setup.py'"'"'; __file__='"'"'C:\\Users\\prash\\AppData\\Local\\Temp\\pip-install-4dzb_fs1\\torch\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\prash\AppData\Local\Temp\pip-record-4gnvoro2\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\ProgramData\Anaconda3\Include\torch' Check the logs for full command output.

# %%
#create features
from fastai.tabular.all import  add_datepart
add_datepart(new_data, 'Date')
new_data.drop('Elapsed', axis=1, inplace=True)  #elapsed will be the time stamp

# %%
#split into train and validation
train = new_data[:987]
valid = new_data[987:]

x_train = train.drop('Close', axis=1)
y_train = train['Close']
x_valid = valid.drop('Close', axis=1)
y_valid = valid['Close']

#implement linear regression
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#make predictions and find the rmse
preds = model.predict(x_valid)
rms=np.sqrt(np.mean(np.power((np.array(y_valid)-np.array(preds)),2)))
rms
# Out:
# 121.16382449873996

# %% [markdown]
# # KNN

# %%
from sklearn import neighbors
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# %%
#scaling data
x_train_scaled = scaler.fit_transform(x_train)
x_train = pd.DataFrame(x_train_scaled)
x_valid_scaled = scaler.fit_transform(x_valid)
x_valid = pd.DataFrame(x_valid_scaled)


params = {'n_neighbors':[2,3,4,5,6,7,8,9]}
knn = neighbors.KNeighborsRegressor()
model = GridSearchCV(knn, params, cv=5)


model.fit(x_train,y_train)
preds = model.predict(x_valid)
print(model)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': [2, 3, 4, 5, 6, 7, 8, 9]})

# %%
#make predictions and find the rmse
preds = model.predict(x_valid)
rms=np.sqrt(np.mean(np.power((np.array(y_valid)-np.array(preds)),2)))
rms
# Out:
# 114.820692914522

# %%
#plot
valid['Predictions'] = 0
valid['Predictions'] = preds
plt.plot(valid[['Close', 'Predictions']])
plt.plot(train['Close'])

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # LSTM

# %%
#importing required libraries
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM

#creating dataframe
data = df.sort_index(ascending=True, axis=0)
new_data = pd.DataFrame(index=range(0,len(df)),columns=['Date', 'Close'])
for i in range(0,len(data)):
    new_data['Date'][i] = data['Date'][i]
    new_data['Close'][i] = data['Close'][i]

#setting index
new_data.index = new_data.Date
new_data.drop('Date', axis=1, inplace=True)

#creating train and test sets
dataset = new_data.values

train = dataset[0:987,:]
valid = dataset[987:,:]

#converting dataset into x_train and y_train
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

x_train, y_train = [], []
for i in range(60,len(train)):
    x_train.append(scaled_data[i-60:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))

# create and fit the LSTM network
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(units=50))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=2)

#predicting 246 values, using past 60 from the train data
inputs = new_data[len(new_data) - len(valid) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)

X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)

X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
closing_price = model.predict(X_test)

closing_price = scaler.inverse_transform(closing_price)
print(closing_price)
model.summary()
# Out:
# Epoch 1/100
# 29/29 - 11s - loss: 0.0069
# Epoch 2/100
# 29/29 - 1s - loss: 0.0014
# Epoch 3/100
# 29/29 - 1s - loss: 7.9625e-04
# Epoch 4/100
# 29/29 - 2s - loss: 7.3603e-04
# Epoch 5/100
# 29/29 - 2s - loss: 7.2936e-04
# Epoch 6/100
# 29/29 - 2s - loss: 6.4474e-04
# Epoch 7/100
# 29/29 - 2s - loss: 6.1846e-04
# Epoch 8/100
# 29/29 - 2s - loss: 5.8275e-04
# Epoch 9/100
# 29/29 - 2s - loss: 5.5710e-04
# Epoch 10/100
# 29/29 - 2s - loss: 5.4613e-04
# Epoch 11/100
# 29/29 - 1s - loss: 5.1092e-04
# Epoch 12/100
# 29/29 - 1s - loss: 4.9693e-04
# Epoch 13/100
# 29/29 - 2s - loss: 5.0144e-04
# Epoch 14/100
# 29/29 - 2s - loss: 4.6945e-04
# Epoch 15/100
# 29/29 - 2s - loss: 4.5651e-04
# Epoch 16/100
# 29/29 - 2s - loss: 4.2334e-04
# Epoch 17/100
# 29/29 - 2s - loss: 4.2893e-04
# Epoch 18/100
# 29/29 - 2s - loss: 4.0423e-04
# Epoch 19/100
# 29/29 - 2s - loss: 3.9185e-04
# Epoch 20/100
# 29/29 - 1s - loss: 4.0726e-04
# Epoch 21/100
# 29/29 - 1s - loss: 3.7564e-04
# Epoch 22/100
# 29/29 - 2s - loss: 3.9822e-04
# Epoch 23/100
# 29/29 - 2s - loss: 3.7055e-04
# Epoch 24/100
# 29/29 - 2s - loss: 3.8509e-04
# Epoch 25/100
# 29/29 - 2s - loss: 3.5204e-04
# Epoch 26/100
# 29/29 - 2s - loss: 3.5649e-04
# Epoch 27/100
# 29/29 - 2s - loss: 3.2664e-04
# Epoch 28/100
# 29/29 - 2s - loss: 3.1664e-04
# Epoch 29/100
# 29/29 - 2s - loss: 3.0937e-04
# Epoch 30/100
# 29/29 - 1s - loss: 3.2192e-04
# Epoch 31/100
# 29/29 - 1s - loss: 2.9235e-04
# Epoch 32/100
# 29/29 - 2s - loss: 2.9317e-04
# Epoch 33/100
# 29/29 - 2s - loss: 2.9231e-04
# Epoch 34/100
# 29/29 - 2s - loss: 2.9841e-04
# Epoch 35/100
# 29/29 - 2s - loss: 2.7195e-04
# Epoch 36/100
# 29/29 - 2s - loss: 2.6586e-04
# Epoch 37/100
# 29/29 - 2s - loss: 2.5605e-04
# Epoch 38/100
# 29/29 - 1s - loss: 2.4924e-04
# Epoch 39/100
# 29/29 - 2s - loss: 2.7027e-04
# Epoch 40/100
# 29/29 - 1s - loss: 2.6310e-04
# Epoch 41/100
# 29/29 - 1s - loss: 2.4211e-04
# Epoch 42/100
# 29/29 - 2s - loss: 2.5704e-04
# Epoch 43/100
# 29/29 - 2s - loss: 2.7191e-04
# Epoch 44/100
# 29/29 - 2s - loss: 2.6466e-04
# Epoch 45/100
# 29/29 - 2s - loss: 2.2983e-04
# Epoch 46/100
# 29/29 - 2s - loss: 2.2716e-04
# Epoch 47/100
# 29/29 - 2s - loss: 2.2123e-04
# Epoch 48/100
# 29/29 - 2s - loss: 2.1452e-04
# Epoch 49/100
# 29/29 - 2s - loss: 2.2807e-04
# Epoch 50/100
# 29/29 - 1s - loss: 2.0691e-04
# Epoch 51/100
# 29/29 - 1s - loss: 2.1111e-04
# Epoch 52/100
# 29/29 - 2s - loss: 2.1220e-04
# Epoch 53/100
# 29/29 - 2s - loss: 2.0285e-04
# Epoch 54/100
# 29/29 - 2s - loss: 2.1863e-04
# Epoch 55/100
# 29/29 - 2s - loss: 2.0880e-04
# Epoch 56/100
# 29/29 - 2s - loss: 2.2660e-04
# Epoch 57/100
# 29/29 - 2s - loss: 2.0370e-04
# Epoch 58/100
# 29/29 - 2s - loss: 1.8305e-04
# Epoch 59/100
# 29/29 - 2s - loss: 1.8172e-04
# Epoch 60/100
# 29/29 - 1s - loss: 2.1396e-04
# Epoch 61/100
# 29/29 - 2s - loss: 1.9293e-04
# Epoch 62/100
# 29/29 - 2s - loss: 1.9261e-04
# Epoch 63/100
# 29/29 - 2s - loss: 1.8007e-04
# Epoch 64/100
# 29/29 - 2s - loss: 1.8582e-04
# Epoch 65/100
# 29/29 - 2s - loss: 1.8232e-04
# Epoch 66/100
# 29/29 - 2s - loss: 1.7705e-04
# Epoch 67/100
# 29/29 - 2s - loss: 1.7801e-04
# Epoch 68/100
# 29/29 - 2s - loss: 1.8407e-04
# Epoch 69/100
# 29/29 - 1s - loss: 1.8196e-04
# Epoch 70/100
# 29/29 - 1s - loss: 1.6753e-04
# Epoch 71/100
# 29/29 - 2s - loss: 1.7198e-04
# Epoch 72/100
# 29/29 - 2s - loss: 1.7231e-04
# Epoch 73/100
# 29/29 - 2s - loss: 1.7546e-04
# Epoch 74/100
# 29/29 - 2s - loss: 1.7656e-04
# Epoch 75/100
# 29/29 - 2s - loss: 1.9281e-04
# Epoch 76/100
# 29/29 - 2s - loss: 1.6451e-04
# Epoch 77/100
# 29/29 - 2s - loss: 1.6306e-04
# Epoch 78/100
# 29/29 - 2s - loss: 1.6511e-04
# Epoch 79/100
# 29/29 - 1s - loss: 1.8286e-04
# Epoch 80/100
# 29/29 - 1s - loss: 1.9045e-04
# Epoch 81/100
# 29/29 - 2s - loss: 1.9466e-04
# Epoch 82/100
# 29/29 - 2s - loss: 1.9914e-04
# Epoch 83/100
# 29/29 - 2s - loss: 1.9159e-04
# Epoch 84/100
# 29/29 - 2s - loss: 1.6428e-04
# Epoch 85/100
# 29/29 - 2s - loss: 1.6000e-04
# Epoch 86/100
# 29/29 - 2s - loss: 1.6834e-04
# Epoch 87/100
# 29/29 - 2s - loss: 1.7061e-04
# Epoch 88/100
# 29/29 - 1s - loss: 1.6904e-04
# Epoch 89/100
# 29/29 - 1s - loss: 1.7362e-04
# Epoch 90/100
# 29/29 - 1s - loss: 1.6378e-04
# Epoch 91/100
# 29/29 - 2s - loss: 1.6788e-04
# Epoch 92/100
# 29/29 - 2s - loss: 1.6651e-04
# Epoch 93/100
# 29/29 - 2s - loss: 1.6172e-04
# Epoch 94/100
# 29/29 - 2s - loss: 1.7216e-04
# Epoch 95/100
# 29/29 - 2s - loss: 1.7304e-04
# Epoch 96/100
# 29/29 - 2s - loss: 1.7650e-04
# Epoch 97/100
# 29/29 - 2s - loss: 1.6752e-04
# Epoch 98/100
# 29/29 - 1s - loss: 1.6625e-04
# Epoch 99/100
# 29/29 - 1s - loss: 1.6749e-04
# Epoch 100/100
# 29/29 - 1s - loss: 1.6902e-04
# [[207.95125]
#  [206.12914]
#  [207.03215]
#  [208.15895]
#  [210.88988]
#  [208.02701]
#  [207.82088]
#  [209.08426]
#  [204.58884]
#  [203.03346]
#  [202.08093]
#  [210.09935]
#  [202.9411 ]
#  [209.266  ]
#  [221.20961]
#  [224.83366]
#  [222.92856]
#  [224.64775]
#  [222.94731]
#  [222.37677]
#  [234.52573]
#  [218.74403]
#  [222.59734]
#  [242.78975]
#  [229.91353]
#  [230.64696]
#  [247.54579]
#  [246.41838]
#  [246.73329]
#  [257.49634]
#  [272.3203 ]
#  [263.00366]
#  [268.05807]
#  [269.18054]
#  [274.01285]
#  [270.8766 ]
#  [285.95145]
#  [269.80783]
#  [286.0097 ]
#  [276.04703]
#  [273.80704]
#  [278.16635]
#  [269.85062]
#  [285.3258 ]
#  [284.20984]
#  [295.57098]
#  [276.54657]
#  [281.8291 ]
#  [282.05392]
#  [284.47925]
#  [288.3992 ]
#  [298.74896]
#  [293.17743]
#  [294.59885]
#  [298.89865]
#  [301.11063]
#  [299.38205]
#  [302.1758 ]
#  [314.25803]
#  [302.89786]
#  [306.31863]
#  [306.9974 ]
#  [307.8719 ]
#  [308.542  ]
#  [314.447  ]
#  [308.15775]
#  [309.86462]
#  [309.19778]
#  [325.77087]
#  [312.6549 ]
#  [309.816  ]
#  [310.64203]
#  [299.90775]
#  [309.80875]
#  [305.72598]
#  [303.78735]
#  [301.3352 ]
#  [302.6666 ]
#  [298.56152]
#  [303.18945]
#  [283.02975]
#  [290.5073 ]
#  [270.63467]
#  [276.9132 ]
#  [266.5542 ]
#  [286.80148]
#  [276.93253]
#  [275.5751 ]
#  [286.2331 ]
#  [276.43933]
#  [276.32977]
#  [273.33585]
#  [264.7164 ]
#  [262.54324]
#  [268.90674]
#  [259.42966]
#  [273.51785]
#  [270.96646]
#  [271.96878]
#  [272.57562]
#  [271.43732]
#  [273.1552 ]
#  [270.66583]
#  [265.03278]
#  [274.03754]
#  [263.589  ]
#  [277.37134]
#  [274.57275]
#  [274.50745]
#  [276.6742 ]
#  [266.49603]
#  [256.3346 ]
#  [264.52274]
#  [262.6584 ]
#  [256.18192]
#  [257.85526]
#  [262.82947]
#  [261.78436]
#  [254.91689]
#  [281.31848]
#  [266.85107]
#  [264.99762]
#  [272.0466 ]
#  [268.61166]
#  [276.18164]
#  [270.20105]
#  [270.41965]
#  [271.43732]
#  [273.10898]
#  [277.55527]
#  [276.89185]
#  [280.98926]
#  [282.06818]
#  [281.5235 ]
#  [278.70355]
#  [280.16028]
#  [287.75345]
#  [286.4191 ]
#  [287.60144]
#  [294.74973]
#  [284.9205 ]
#  [281.96664]
#  [286.94247]
#  [292.9119 ]
#  [282.9993 ]
#  [290.79373]
#  [279.2591 ]
#  [287.36685]
#  [242.90497]
#  [247.27277]
#  [247.42204]
#  [252.39702]
#  [244.82886]
#  [244.70499]
#  [249.15918]
#  [250.18628]
#  [254.07288]
#  [256.24057]
#  [258.31454]
#  [253.28831]
#  [264.4632 ]
#  [266.1542 ]
#  [256.64532]
#  [251.28175]
#  [266.0508 ]
#  [262.26144]
#  [263.90475]
#  [263.72412]
#  [259.63962]
#  [266.82162]
#  [266.55353]
#  [276.361  ]
#  [264.65115]
#  [273.83258]
#  [260.5489 ]
#  [258.1689 ]
#  [257.68027]
#  [262.72055]
#  [262.97604]
#  [265.5445 ]
#  [261.95444]
#  [261.26813]
#  [269.0133 ]
#  [259.05933]
#  [284.08286]
#  [268.659  ]
#  [265.7384 ]
#  [263.59995]
#  [276.5898 ]
#  [269.7232 ]
#  [265.17355]
#  [262.70984]
#  [256.2897 ]
#  [239.17174]
#  [253.16042]
#  [236.18843]
#  [233.63379]
#  [242.7084 ]
#  [244.09639]
#  [245.52078]
#  [232.62923]
#  [240.2696 ]
#  [242.33997]
#  [240.15938]
#  [246.62267]
#  [230.07307]
#  [235.74644]
#  [234.2614 ]
#  [239.76015]
#  [235.22633]
#  [234.66206]
#  [236.51593]
#  [231.01137]
#  [234.0363 ]
#  [237.09941]
#  [237.64233]
#  [241.62868]
#  [242.77103]
#  [236.26253]
#  [232.61322]
#  [229.31664]
#  [238.31241]
#  [230.39511]
#  [233.71843]
#  [235.10355]
#  [231.89275]
#  [235.91118]
#  [218.54622]
#  [222.77005]
#  [221.25772]
#  [223.04587]
#  [221.13892]
#  [213.93758]
#  [224.34007]
#  [235.27032]
#  [233.51707]
#  [231.26035]
#  [232.4763 ]
#  [232.14697]
#  [230.7048 ]
#  [234.91081]
#  [231.3131 ]
#  [231.04413]
#  [232.27417]
#  [228.29042]
#  [225.52615]
#  [215.28227]
#  [207.80127]]
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 60, 50)            10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
rms=np.sqrt(np.mean(np.power((valid-closing_price),2)))
rms
# Out:
# 6.961019776230057

# %%
#for plotting
train = new_data[:987]
valid = new_data[987:]
valid['Predictions'] = closing_price
plt.plot(train['Close'])
plt.plot(valid[['Close','Predictions']])

# %% [markdown]
# ![image.png](attachment:image.png)
